# %% [markdown]
# #### See where your python.exe is located

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\HP\Python\python.exe

# %% [markdown]
# #### See your working directory

# %%
import os
print(os.getcwd())
# Out:
# e:\OpenCV\Basics of Computer Vision and OpenCV

# %% [markdown]
# #### Test your imports

# %%
import cv2
import numpy as np
import matplotlib

# %% [markdown]
# #### Display the version of OpenCV

# %%
print (cv2.__version__)
# Out:
# 4.3.0
